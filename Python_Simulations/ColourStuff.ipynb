# %%
numlines = 20

for i in np.linspace(0,1, numlines):
    plt.plot(np.arange(numlines),np.tile([i],numlines), linewidth=4, color=plt.cm.RdYlBu(i))

# %%
numlines = 20

for i in np.linspace(0,1, numlines):
    plt.plot(np.arange(numlines),np.tile([i],numlines), linewidth=4, color=plt.cm.hsv(i))
# Out:
# 0.0
# 0.0526315789474
# 0.105263157895
# 0.157894736842
# 0.210526315789
# 0.263157894737
# 0.315789473684
# 0.368421052632
# 0.421052631579
# 0.473684210526
# 0.526315789474
# 0.578947368421
# 0.631578947368
# 0.684210526316
# 0.736842105263
# 0.789473684211
# 0.842105263158
# 0.894736842105
# 0.947368421053
# 1.0

# %%
numlines = 20

for i in np.linspace(0,1, numlines):
    plt.plot(np.arange(numlines),np.tile([i],numlines), linewidth=4, color=plt.cm.hsv_r(i))
